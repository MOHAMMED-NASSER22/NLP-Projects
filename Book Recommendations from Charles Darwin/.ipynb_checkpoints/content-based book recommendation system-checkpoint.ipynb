# %% [markdown]
# ## 1. Darwin's bibliography
# <p><img src="https://assets.datacamp.com/production/project_607/img/CharlesDarwin.jpg" alt="Charles Darwin" width="300px"></p>
# <p>Charles Darwin is one of the few universal figures of science. His most renowned work is without a doubt his "<em>On the Origin of Species</em>" published in 1859 which introduced the concept of natural selection. But Darwin wrote many other books on a wide range of topics, including geology, plants or his personal life. In this notebook, we will automatically detect how closely related his books are to each other.</p>
# <p>To this purpose, we will develop the bases of <strong>a content-based book recommendation system</strong>, which will determine which books are close to each other based on how similar the discussed topics are. The methods we will use are commonly used in text- or documents-heavy industries such as legal, tech or customer support to perform some common task such as text classification or handling search engine queries.</p>
# <p>Let's take a look at the books we'll use in our recommendation system.</p>

# %%
# Import library
import glob

# The books files are contained in this folder
folder = "datasets/"

# List all the .txt files and sort them alphabetically
files = glob.glob(folder + "*.txt")
files.sort()
files
# Out:
# ['datasets\\Autobiography.txt',
#  'datasets\\CoralReefs.txt',
#  'datasets\\DescentofMan.txt',
#  'datasets\\DifferentFormsofFlowers.txt',
#  'datasets\\EffectsCrossSelfFertilization.txt',
#  'datasets\\ExpressionofEmotionManAnimals.txt',
#  'datasets\\FormationVegetableMould.txt',
#  'datasets\\FoundationsOriginofSpecies.txt',
#  'datasets\\GeologicalObservationsSouthAmerica.txt',
#  'datasets\\InsectivorousPlants.txt',
#  'datasets\\LifeandLettersVol1.txt',
#  'datasets\\LifeandLettersVol2.txt',
#  'datasets\\MonographCirripedia.txt',
#  'datasets\\MonographCirripediaVol2.txt',
#  'datasets\\MovementClimbingPlants.txt',
#  'datasets\\OriginofSpecies.txt',
#  'datasets\\PowerMovementPlants.txt',
#  'datasets\\VariationPlantsAnimalsDomestication.txt',
#  'datasets\\VolcanicIslands.txt',
#  'datasets\\VoyageBeagle.txt']

# %% [markdown]
# ## 2. Load the contents of each book into Python
# <p>As a first step, we need to load the content of these books into Python and do some basic pre-processing to facilitate the downstream analyses. We call such a collection of texts <strong>a corpus</strong>. We will also store the titles for these books for future reference and print their respective length to get a gauge for their contents.</p>

# %%
# Import libraries
import re, os

# Initialize the object that will contain the texts and titles
txts = []
titles = []

for n in files:
    # Open each file
    f = open(n, encoding='utf-8-sig')
    # Remove all non-alpha-numeric characters
    data = re.sub('[\W]+' , ' ' , f.read())
    # Store the texts and titles of the books in two separate lists
    txts.append(data)
    titles.append(os.path.basename(n).replace('.txt',''))

# Print the length, in characters, of each book
[len(t) for t in txts]
# Out:
# [123235,
#  496068,
#  1776539,
#  617088,
#  913713,
#  624665,
#  335920,
#  525423,
#  797401,
#  901406,
#  1047518,
#  1010645,
#  773930,
#  1678048,
#  298319,
#  916536,
#  1093606,
#  1046071,
#  341447,
#  1149668]

# %% [markdown]
# ## 3. Find "On the Origin of Species"
# <p>For the next parts of this analysis, we will often check the results returned by our method for a given book. For consistency, we will refer to Darwin's most famous book: "<em>On the Origin of Species</em>." Let's find to which index this book is associated.</p>

# %%
# Browse the list containing all the titles
for i in range(len(titles)):
    # Store the index if the title is "OriginofSpecies"
    if(titles[i]=="OriginofSpecies"):
        ori = i
 
# Print the stored index
print(str(ori))
# Out:
# 15

# %% [markdown]
# ## 4. Tokenize the corpus
# <p>As a next step, we need to transform the corpus into a format that is easier to deal with for the downstream analyses. We will tokenize our corpus, i.e., transform each text into a list of the individual words (called tokens) it is made of. To check the output of our process, we will print the first 20 tokens of "<em>On the Origin of Species</em>".</p>

# %%
# Define a list of stop words
stoplist = set('for a of the and to in to be which some is at that we i who whom show via may my our might as well'.split())

# Convert the text to lower case 
txts_lower_case = [txt.lower() for txt in txts]

# Transform the text into tokens 
txts_split = [txt.split() for txt in txts_lower_case]

# Remove tokens which are part of the list of stop words
texts = [[word for word in txt if word not in stoplist] for txt in txts_split]

# Print the first 20 tokens for the "On the Origin of Species" book
texts[ori][:20]
# Out:
# ['on',
#  'origin',
#  'species',
#  'but',
#  'with',
#  'regard',
#  'material',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'this',
#  'can',
#  'perceive',
#  'events',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 5. Stemming of the tokenized corpus
# <p>If you have read <em>On the Origin of Species</em>, you will have noticed that Charles Darwin can use different words to refer to a similar concept. For example, the concept of selection can be described by words such as <em>selection</em>, <em>selective</em>, <em>select</em> or <em>selects</em>. This will dilute the weight given to this concept in the book and potentially bias the results of the analysis.</p>
# <p>To solve this issue, it is a common practice to use a <strong>stemming process</strong>, which will group together the inflected forms of a word so they can be analysed as a single item: <strong>the stem</strong>. In our <em>On the Origin of Species</em> example, the words related to the concept of selection would be gathered under the <em>select</em> stem.</p>
# <p>As we are analysing 20 full books, the stemming algorithm can take several minutes to run and, in order to make the process faster, we will directly load the final results from a pickle file and review the method used to generate it.</p>

# %%
# Load the Porter stemming function from the nltk package
from nltk.stem import PorterStemmer

# Create an instance of a PorterStemmer object
porter = PorterStemmer()

# For each token of each text, we generated its stem 
texts_stem = [[porter.stem(token) for token in text] for text in texts]

# %% [markdown]
# ## 6. Building a bag-of-words model
# <p>Now that we have transformed the texts into stemmed tokens, we need to build models that will be useable by downstream algorithms.</p>
# <p>First, we need to will create a universe of all words contained in our corpus of Charles Darwin's books, which we call <em>a dictionary</em>. Then, using the stemmed tokens and the dictionary, we will create <strong>bag-of-words models</strong> (BoW) of each of our texts. The BoW models will represent our books as a list of all uniques tokens they contain associated with their respective number of occurrences. </p>
# <p>To better understand the structure of such a model, we will print the five first elements of one of the "<em>On the Origin of Species</em>" BoW model.</p>

# %%
# Load the functions allowing to create and use dictionaries
from gensim import corpora

# Create a dictionary from the stemmed tokens
dictionary = corpora.Dictionary(texts_stem)

# Create a bag-of-words model for each book, using the previously generated dictionary
bows = [dictionary.doc2bow(text) for text in texts_stem]

# Print the first five elements of the On the Origin of species' BoW model
bows[ori][0:5]
# Out:
# [(0, 11), (5, 51), (6, 1), (8, 2), (21, 1)]

# %% [markdown]
# ## 7. The most common words of a given book
# <p>The results returned by the bag-of-words model is certainly easy to use for a computer but hard to interpret for a human. It is not straightforward to understand which stemmed tokens are present in a given book from Charles Darwin, and how many occurrences we can find.</p>
# <p>In order to better understand how the model has been generated and visualize its content, we will transform it into a DataFrame and display the 10 most common stems for the book "<em>On the Origin of Species</em>".</p>

# %%
# Import pandas to create and manipulate DataFrames
import pandas as pd

# Convert the BoW model for "On the Origin of Species" into a DataFrame
df_bow_origin = pd.DataFrame(bows[ori])

# Add the column names to the DataFrame
df_bow_origin.columns = ["index", "occurrences"]

# Add a column containing the token corresponding to the dictionary index
df_bow_origin['token'] = [dictionary[index] for index in df_bow_origin['index']]

# Sort the DataFrame by descending number of occurrences and print the first 10 values
df_bow_origin.sort_values(by="occurrences", ascending=False).head(10)
# Out:
#       index  occurrences  token
# 747    1169         2023   have
# 1117   1737         1544     on
# 1487   2289         1542  speci
# 891    1367         1480     it
# 238     394         1362     by
# 1126   1748         1201     or
# 125     220         1140    are
# 664    1044         1137   from
# 1772   2704         1000   with
# 1607   2453          962    thi

# %% [markdown]
# ## 8. Build a tf-idf model
# <p>If it wasn't for the presence of the stem "<em>speci</em>", we would have a hard time to guess this BoW model comes from the <em>On the Origin of Species</em> book. The most recurring words are, apart from few exceptions, very common and unlikely to carry any information peculiar to the given book. We need to use an additional step in order to determine which tokens are the most specific to a book.</p>
# <p>To do so, we will use a <strong>tf-idf model</strong> (term frequency–inverse document frequency). This model defines the importance of each word depending on how frequent it is in this text and how infrequent it is in all the other documents. As a result, a high tf-idf score for a word will indicate that this word is specific to this text.</p>
# <p>After computing those scores, we will print the 10 words most specific to the "<em>On the Origin of Species</em>" book (i.e., the 10 words with the highest tf-idf score).</p>

# %%
# Load the gensim functions that will allow us to generate tf-idf models
from gensim.models import TfidfModel

# Generate the tf-idf model
model = TfidfModel(bows)

# Print the model for "On the Origin of Species"
model[bows[ori]]
# Out:
# [(8, 0.00020198030357808226),
#  (21, 0.0005664104150608586),
#  (23, 0.0016963165499021603),
#  (27, 0.0006399593379424799),
#  (28, 0.00254447482485324),
#  (31, 0.0008481582749510801),
#  (35, 0.0010057524652653262),
#  (36, 0.0010057524652653262),
#  (51, 0.00043934205020446744),
#  (54, 0.0020115049305306524),
#  (56, 0.0023541342069098655),
#  (57, 0.00010099015178904113),
#  (63, 0.0027294421156885138),
#  (64, 0.0005049507589452056),
#  (66, 0.00020198030357808226),
#  (67, 0.0023541342069098655),
#  (68, 0.0020115049305306524),
#  (75, 0.0013647210578442569),
#  (76, 0.00043934205020446744),
#  (78, 0.0041339398052135205),
#  (82, 0.0020669699026067603),
#  (85, 0.008496156225912878),
#  (86, 0.0005049507589452056),
#  (90, 0.002423763642936987),
#  (91, 0.0033326750090383575),
#  (92, 0.0008786841004089349),
#  (93, 0.0016595345798554252),
#  (96, 0.0008786841004089349),
#  (97, 0.00043934205020446744),
#  (98, 0.0035147364016357395),
#  (99, 0.001615842428624658),
#  (104, 0.037344074267379734),
#  (106, 0.0009089113661013701),
#  (108, 0.0014044976895250065),
#  (110, 0.003511244223812516),
#  (111, 0.0052514878930301385),
#  (113, 0.002221783339358905),
#  (116, 0.0015148522768356168),
#  (2310, 0.014080534513714566),
#  (2312, 0.00818832634706554),
#  (2314, 0.0073633353957911615),
#  (2316, 0.0008786841004089349),
#  (2318, 0.002221783339358905),
#  (2320, 0.0022656416602434342),
#  (2321, 0.0030753943514312725),
#  (2323, 0.0039540784518402065),
#  (2326, 0.14683985992873763),
#  (2329, 0.0010057524652653262),
#  (2331, 0.042480781129564396),
#  (2333, 0.0020744182248192814),
#  (2336, 0.00396487290542601),
#  (2337, 0.011063277117918588),
#  (2338, 0.00314432576065237),
#  (2340, 0.0030297045536712337),
#  (2341, 0.03684746856179494),
#  (2343, 0.0014520927573734971),
#  (2344, 0.00254447482485324),
#  (2345, 0.0014520927573734971),
#  (2347, 0.004915741913337523),
#  (2350, 0.0033926330998043206),
#  (2353, 0.0013180261506134023),
#  (2354, 0.00095993900691372),
#  (2358, 0.06811813794196281),
#  (2360, 0.001572162880326185),
#  (2362, 0.0026257439465150693),
#  (2364, 0.0006399593379424799),
#  (2365, 0.007372281080600003),
#  (2369, 0.02715531656216381),
#  (2370, 0.004213493068575019),
#  (2371, 0.0013647210578442569),
#  (2376, 0.007908156903680413),
#  (2377, 0.0031306947054602747),
#  (2378, 0.0030297045536712337),
#  (2379, 0.008496156225912878),
#  (2382, 0.0020115049305306524),
#  (2383, 0.0016595345798554252),
#  (2384, 0.0008786841004089349),
#  (2386, 0.0006399593379424799),
#  (2388, 0.00031997966897123997),
#  (2390, 0.004213493068575019),
#  (2393, 0.0006223254674457845),
#  (2394, 0.0020198030357808225),
#  (2397, 0.006200909707820281),
#  (2400, 0.010983551255111688),
#  (2402, 0.0010057524652653262),
#  (2409, 0.016387903976072322),
#  (2410, 0.018833073655278924),
#  (2418, 0.0007022488447625033),
#  (2419, 0.00409416317353277),
#  (2420, 0.0013647210578442569),
#  (2421, 0.0013180261506134023),
#  (2422, 0.010544209204907218),
#  (2423, 0.014058945606542958),
#  (2424, 0.00191987801382744),
#  (2432, 0.0005664104150608586),
#  (2433, 0.0031306947054602747),
#  (2434, 0.00010099015178904113),
#  (2435, 0.0020744182248192814),
#  (2445, 0.0005664104150608586),
#  (2447, 0.02883441332498801),
#  ...]

# %% [markdown]
# ## 9. The results of the tf-idf model
# <p>Once again, the format of those results is hard to interpret for a human. Therefore, we will transform it into a more readable version and display the 10 most specific words for the "<em>On the Origin of Species</em>" book.</p>

# %%
# Convert the tf-idf model for "On the Origin of Species" into a DataFrame
df_tfidf = pd.DataFrame(model[bows[ori]])

# Name the columns of the DataFrame id and score
df_tfidf.columns =['id' , 'score']
# Add the tokens corresponding to the numerical indices for better readability
df_tfidf['token'] = [dictionary[i] for i in list(df_tfidf['id'])]

# Sort the DataFrame by descending tf-idf score and print the first 10 rows.
df_tfidf.sort_values(by="score", ascending=False).head(10)
# Out:
#          id     score    token
# 879    2165  0.323034   select
# 3100  10110  0.202055   pigeon
# 127     370  0.195925    breed
# 2982   9397  0.165974   migrat
# 946    2326  0.146840   steril
# 284     753  0.144663   domest
# 3668  14077  0.130376        _
# 503    1256  0.126405   hybrid
# 370     967  0.125527   fertil
# 3864  16581  0.123261  gärtner

# %% [markdown]
# ## 10. Compute distance between texts
# <p>The results of the tf-idf algorithm now return stemmed tokens which are specific to each book. We can, for example, see that topics such as selection, breeding or domestication are defining "<em>On the Origin of Species</em>" (and yes, in this book, Charles Darwin talks quite a lot about pigeons too). Now that we have a model associating tokens to how specific they are to each book, we can measure how related to books are between each other.</p>
# <p>To this purpose, we will use a measure of similarity called <strong>cosine similarity</strong> and we will visualize the results as a distance matrix, i.e., a matrix showing all pairwise distances between Darwin's books.</p>

# %%
# Load the library allowing similarity computations
from gensim import similarities

# Compute the similarity matrix (pairwise distance between all texts)
sims = similarities.MatrixSimilarity(model[bows])

# Transform the resulting list into a dataframe
sim_df = pd.DataFrame(list(sims))

# Add the titles of the books as columns and index of the dataframe
sim_df.columns = titles
sim_df.index = titles
# Print the resulting matrix
sim_df
# Out:
#                                      Autobiography  CoralReefs  DescentofMan  \
# Autobiography                             1.000000    0.049597      0.080753
# CoralReefs                                0.049597    1.000000      0.009516
# DescentofMan                              0.080753    0.009516      1.000000
# DifferentFormsofFlowers                   0.066496    0.001981      0.072622
# EffectsCrossSelfFertilization             0.076738    0.001937      0.029935
# ExpressionofEmotionManAnimals             0.088927    0.005048      0.147348
# FormationVegetableMould                   0.041152    0.029451      0.027087
# FoundationsOriginofSpecies                0.026507    0.010080      0.061509
# GeologicalObservationsSouthAmerica        0.030605    0.060813      0.009651
# InsectivorousPlants                       0.014920    0.002284      0.009461
# LifeandLettersVol1                        0.399303    0.031210      0.060136
# LifeandLettersVol2                        0.220457    0.017760      0.080856
# MonographCirripedia                       0.005663    0.005945      0.051471
# MonographCirripediaVol2                   0.007126    0.008975      0.036502
# MovementClimbingPlants                    0.022955    0.001544      0.005185
# OriginofSpecies                           0.099784    0.038795      0.264207
# PowerMovementPlants                       0.016030    0.002692      0.011267
# VariationPlantsAnimalsDomestication       0.044630    0.010392      0.207258
# VolcanicIslands                           0.038559    0.057402      0.007883
# VoyageBeagle                              0.184152    0.267361      0.123982
#
#                                      DifferentFormsofFlowers  \
# Autobiography                                       0.066496
# CoralReefs                                          0.001981
# DescentofMan                                        0.072622
# DifferentFormsofFlowers                             1.000000
# EffectsCrossSelfFertilization                       0.391114
# ExpressionofEmotionManAnimals                       0.006579
# FormationVegetableMould                             0.010627
# FoundationsOriginofSpecies                          0.017600
# GeologicalObservationsSouthAmerica                  0.002900
# InsectivorousPlants                                 0.007485
# LifeandLettersVol1                                  0.016210
# LifeandLettersVol2                                  0.046700
# MonographCirripedia                                 0.008945
# MonographCirripediaVol2                             0.004452
# MovementClimbingPlants                              0.008241
# OriginofSpecies                                     0.127265
# PowerMovementPlants                                 0.018888
# VariationPlantsAnimalsDomestication                 0.044470
# VolcanicIslands                                     0.002625
# VoyageBeagle                                        0.013231
#
#                                      EffectsCrossSelfFertilization  \
# Autobiography                                             0.076738
# CoralReefs                                                0.001937
# DescentofMan                                              0.029935
# DifferentFormsofFlowers                                   0.391114
# EffectsCrossSelfFertilization                             1.000000
# ExpressionofEmotionManAnimals                             0.006865
# FormationVegetableMould                                   0.032273
# FoundationsOriginofSpecies                                0.016763
# GeologicalObservationsSouthAmerica                        0.002251
# InsectivorousPlants                                       0.006764
# LifeandLettersVol1                                        0.019620
# LifeandLettersVol2                                        0.046543
# MonographCirripedia                                       0.003006
# MonographCirripediaVol2                                   0.002354
# MovementClimbingPlants                                    0.015057
# OriginofSpecies                                           0.144344
# PowerMovementPlants                                       0.039900
# VariationPlantsAnimalsDomestication                       0.048573
# VolcanicIslands                                           0.002181
# VoyageBeagle                                              0.017212
#
#                                      ExpressionofEmotionManAnimals  \
# Autobiography                                             0.088927
# CoralReefs                                                0.005048
# DescentofMan                                              0.147348
# DifferentFormsofFlowers                                   0.006579
# EffectsCrossSelfFertilization                             0.006865
# ExpressionofEmotionManAnimals                             1.000000
# FormationVegetableMould                                   0.021057
# FoundationsOriginofSpecies                                0.022913
# GeologicalObservationsSouthAmerica                        0.005227
# InsectivorousPlants                                       0.011496
# LifeandLettersVol1                                        0.065240
# LifeandLettersVol2                                        0.049239
# MonographCirripedia                                       0.018505
# MonographCirripediaVol2                                   0.027059
# MovementClimbingPlants                                    0.005979
# OriginofSpecies                                           0.063346
# PowerMovementPlants                                       0.011266
# VariationPlantsAnimalsDomestication                       0.076320
# VolcanicIslands                                           0.005601
# VoyageBeagle                                              0.098991
#
#                                      FormationVegetableMould  \
# Autobiography                                       0.041152
# CoralReefs                                          0.029451
# DescentofMan                                        0.027087
# DifferentFormsofFlowers                             0.010627
# EffectsCrossSelfFertilization                       0.032273
# ExpressionofEmotionManAnimals                       0.021057
# FormationVegetableMould                             1.000000
# FoundationsOriginofSpecies                          0.009821
# GeologicalObservationsSouthAmerica                  0.067694
# InsectivorousPlants                                 0.035507
# LifeandLettersVol1                                  0.028420
# LifeandLettersVol2                                  0.023996
# MonographCirripedia                                 0.019377
# MonographCirripediaVol2                             0.020745
# MovementClimbingPlants                              0.038828
# OriginofSpecies                                     0.049055
# PowerMovementPlants                                 0.039905
# VariationPlantsAnimalsDomestication                 0.029612
# VolcanicIslands                                     0.059299
# VoyageBeagle                                        0.098317
#
#                                      FoundationsOriginofSpecies  \
# Autobiography                                          0.026507
# CoralReefs                                             0.010080
# DescentofMan                                           0.061509
# DifferentFormsofFlowers                                0.017600
# EffectsCrossSelfFertilization                          0.016763
# ExpressionofEmotionManAnimals                          0.022913
# FormationVegetableMould                                0.009821
# FoundationsOriginofSpecies                             0.999999
# GeologicalObservationsSouthAmerica                     0.012463
# InsectivorousPlants                                    0.002746
# LifeandLettersVol1                                     0.026277
# LifeandLettersVol2                                     0.024771
# MonographCirripedia                                    0.081520
# MonographCirripediaVol2                                0.097443
# MovementClimbingPlants                                 0.001785
# OriginofSpecies                                        0.173830
# PowerMovementPlants                                    0.003951
# VariationPlantsAnimalsDomestication                    0.116588
# VolcanicIslands                                        0.008002
# VoyageBeagle                                           0.040700
#
#                                      GeologicalObservationsSouthAmerica  \
# Autobiography                                                  0.030605
# CoralReefs                                                     0.060813
# DescentofMan                                                   0.009651
# DifferentFormsofFlowers                                        0.002900
# EffectsCrossSelfFertilization                                  0.002251
# ExpressionofEmotionManAnimals                                  0.005227
# FormationVegetableMould                                        0.067694
# FoundationsOriginofSpecies                                     0.012463
# GeologicalObservationsSouthAmerica                             1.000000
# InsectivorousPlants                                            0.006850
# LifeandLettersVol1                                             0.028711
# LifeandLettersVol2                                             0.012253
# MonographCirripedia                                            0.008762
# MonographCirripediaVol2                                        0.018954
# MovementClimbingPlants                                         0.002049
# OriginofSpecies                                                0.052309
# PowerMovementPlants                                            0.003458
# VariationPlantsAnimalsDomestication                            0.012441
# VolcanicIslands                                                0.372185
# VoyageBeagle                                                   0.259431
#
#                                      InsectivorousPlants  LifeandLettersVol1  \
# Autobiography                                   0.014920            0.399303
# CoralReefs                                      0.002284            0.031210
# DescentofMan                                    0.009461            0.060136
# DifferentFormsofFlowers                         0.007485            0.016210
# EffectsCrossSelfFertilization                   0.006764            0.019620
# ExpressionofEmotionManAnimals                   0.011496            0.065240
# FormationVegetableMould                         0.035507            0.028420
# FoundationsOriginofSpecies                      0.002746            0.026277
# GeologicalObservationsSouthAmerica              0.006850            0.028711
# InsectivorousPlants                             1.000000            0.006067
# LifeandLettersVol1                              0.006067            1.000000
# LifeandLettersVol2                              0.016539            0.884887
# MonographCirripedia                             0.018587            0.005434
# MonographCirripediaVol2                         0.017006            0.010617
# MovementClimbingPlants                          0.248966            0.005547
# OriginofSpecies                                 0.014815            0.097219
# PowerMovementPlants                             0.022852            0.009447
# VariationPlantsAnimalsDomestication             0.009324            0.049974
# VolcanicIslands                                 0.008527            0.026522
# VoyageBeagle                                    0.014757            0.172806
#
#                                      LifeandLettersVol2  MonographCirripedia  \
# Autobiography                                  0.220457             0.005663
# CoralReefs                                     0.017760             0.005945
# DescentofMan                                   0.080856             0.051471
# DifferentFormsofFlowers                        0.046700             0.008945
# EffectsCrossSelfFertilization                  0.046543             0.003006
# ExpressionofEmotionManAnimals                  0.049239             0.018505
# FormationVegetableMould                        0.023996             0.019377
# FoundationsOriginofSpecies                     0.024771             0.081520
# GeologicalObservationsSouthAmerica             0.012253             0.008762
# InsectivorousPlants                            0.016539             0.018587
# LifeandLettersVol1                             0.884887             0.005434
# LifeandLettersVol2                             1.000000             0.004725
# MonographCirripedia                            0.004725             1.000000
# MonographCirripediaVol2                        0.008945             0.563623
# MovementClimbingPlants                         0.017671             0.011348
# OriginofSpecies                                0.096385             0.076949
# PowerMovementPlants                            0.012014             0.017703
# VariationPlantsAnimalsDomestication            0.045668             0.073048
# VolcanicIslands                                0.011924             0.009863
# VoyageBeagle                                   0.090716             0.013867
#
#                                      MonographCirripediaVol2  \
# Autobiography                                       0.007126
# CoralReefs                                          0.008975
# DescentofMan                                        0.036502
# DifferentFormsofFlowers                             0.004452
# EffectsCrossSelfFertilization                       0.002354
# ExpressionofEmotionManAnimals                       0.027059
# FormationVegetableMould                             0.020745
# FoundationsOriginofSpecies                          0.097443
# GeologicalObservationsSouthAmerica                  0.018954
# InsectivorousPlants                                 0.017006
# LifeandLettersVol1                                  0.010617
# LifeandLettersVol2                                  0.008945
# MonographCirripedia                                 0.563623
# MonographCirripediaVol2                             1.000000
# MovementClimbingPlants                              0.005756
# OriginofSpecies                                     0.084842
# PowerMovementPlants                                 0.019084
# VariationPlantsAnimalsDomestication                 0.088499
# VolcanicIslands                                     0.014077
# VoyageBeagle                                        0.021111
#
#                                      MovementClimbingPlants  OriginofSpecies  \
# Autobiography                                      0.022955         0.099784
# CoralReefs                                         0.001544         0.038795
# DescentofMan                                       0.005185         0.264207
# DifferentFormsofFlowers                            0.008241         0.127265
# EffectsCrossSelfFertilization                      0.015057         0.144344
# ExpressionofEmotionManAnimals                      0.005979         0.063346
# FormationVegetableMould                            0.038828         0.049055
# FoundationsOriginofSpecies                         0.001785         0.173830
# GeologicalObservationsSouthAmerica                 0.002049         0.052309
# InsectivorousPlants                                0.248966         0.014815
# LifeandLettersVol1                                 0.005547         0.097219
# LifeandLettersVol2                                 0.017671         0.096385
# MonographCirripedia                                0.011348         0.076949
# MonographCirripediaVol2                            0.005756         0.084842
# MovementClimbingPlants                             1.000000         0.008764
# OriginofSpecies                                    0.008764         1.000000
# PowerMovementPlants                                0.104298         0.017974
# VariationPlantsAnimalsDomestication                0.010144         0.375740
# VolcanicIslands                                    0.002843         0.035543
# VoyageBeagle                                       0.012356         0.163446
#
#                                      PowerMovementPlants  \
# Autobiography                                   0.016030
# CoralReefs                                      0.002692
# DescentofMan                                    0.011267
# DifferentFormsofFlowers                         0.018888
# EffectsCrossSelfFertilization                   0.039900
# ExpressionofEmotionManAnimals                   0.011266
# FormationVegetableMould                         0.039905
# FoundationsOriginofSpecies                      0.003951
# GeologicalObservationsSouthAmerica              0.003458
# InsectivorousPlants                             0.022852
# LifeandLettersVol1                              0.009447
# LifeandLettersVol2                              0.012014
# MonographCirripedia                             0.017703
# MonographCirripediaVol2                         0.019084
# MovementClimbingPlants                          0.104298
# OriginofSpecies                                 0.017974
# PowerMovementPlants                             1.000000
# VariationPlantsAnimalsDomestication             0.017946
# VolcanicIslands                                 0.003786
# VoyageBeagle                                    0.023986
#
#                                      VariationPlantsAnimalsDomestication  \
# Autobiography                                                   0.044630
# CoralReefs                                                      0.010392
# DescentofMan                                                    0.207258
# DifferentFormsofFlowers                                         0.044470
# EffectsCrossSelfFertilization                                   0.048573
# ExpressionofEmotionManAnimals                                   0.076320
# FormationVegetableMould                                         0.029612
# FoundationsOriginofSpecies                                      0.116588
# GeologicalObservationsSouthAmerica                              0.012441
# InsectivorousPlants                                             0.009324
# LifeandLettersVol1                                              0.049974
# LifeandLettersVol2                                              0.045668
# MonographCirripedia                                             0.073048
# MonographCirripediaVol2                                         0.088499
# MovementClimbingPlants                                          0.010144
# OriginofSpecies                                                 0.375740
# PowerMovementPlants                                             0.017946
# VariationPlantsAnimalsDomestication                             1.000000
# VolcanicIslands                                                 0.011151
# VoyageBeagle                                                    0.102322
#
#                                      VolcanicIslands  VoyageBeagle
# Autobiography                               0.038559      0.184152
# CoralReefs                                  0.057402      0.267361
# DescentofMan                                0.007883      0.123982
# DifferentFormsofFlowers                     0.002625      0.013231
# EffectsCrossSelfFertilization               0.002181      0.017212
# ExpressionofEmotionManAnimals               0.005601      0.098991
# FormationVegetableMould                     0.059299      0.098317
# FoundationsOriginofSpecies                  0.008002      0.040700
# GeologicalObservationsSouthAmerica          0.372185      0.259431
# InsectivorousPlants                         0.008527      0.014757
# LifeandLettersVol1                          0.026522      0.172806
# LifeandLettersVol2                          0.011924      0.090716
# MonographCirripedia                         0.009863      0.013867
# MonographCirripediaVol2                     0.014077      0.021111
# MovementClimbingPlants                      0.002843      0.012356
# OriginofSpecies                             0.035543      0.163446
# PowerMovementPlants                         0.003786      0.023986
# VariationPlantsAnimalsDomestication         0.011151      0.102322
# VolcanicIslands                             1.000000      0.137999
# VoyageBeagle                                0.137999      1.000000

# %% [markdown]
# ## 11. The book most similar to "On the Origin of Species"
# <p>We now have a matrix containing all the similarity measures between any pair of books from Charles Darwin! We can now use this matrix to quickly extract the information we need, i.e., the distance between one book and one or several others. </p>
# <p>As a first step, we will display which books are the most similar to "<em>On the Origin of Species</em>," more specifically we will produce a bar chart showing all books ranked by how similar they are to Darwin's landmark work.</p>

# %%
# This is needed to display plots in a notebook
# %matplotlib inline

# Import libraries
import matplotlib.pyplot as plt

# Select the column corresponding to "On the Origin of Species" and 
v = sim_df["OriginofSpecies"]

# Sort by ascending scores
v_sorted = v.sort_values(ascending=True)

# Plot this data has a horizontal bar plot
v_sorted.plot.barh(x='lab', y='val', rot=0).plot()
# Modify the axes labels and plot title for a better readability
plt.xlabel("Cosine distance")
plt.ylabel("")
plt.title("Most similar books to 'On the Origin of Species'");

# %% [markdown]
# ## 12. Which books have similar content?
# <p>This turns out to be extremely useful if we want to determine a given book's most similar work. For example, we have just seen that if you enjoyed "<em>On the Origin of Species</em>," you can read books discussing similar concepts such as "<em>The Variation of Animals and Plants under Domestication</em>" or "<em>The Descent of Man, and Selection in Relation to Sex</em>." If you are familiar with Darwin's work, these suggestions will likely seem natural to you. Indeed, <em>On the Origin of Species</em> has a whole chapter about domestication and <em>The Descent of Man, and Selection in Relation to Sex</em> applies the theory of natural selection to human evolution. Hence, the results make sense.</p>
# <p>However, we now want to have a better understanding of the big picture and see how Darwin's books are generally related to each other (in terms of topics discussed). To this purpose, we will represent the whole similarity matrix as a dendrogram, which is a standard tool to display such data. <strong>This last approach will display all the information about book similarities at once.</strong> For example, we can find a book's closest relative but, also, we can visualize which groups of books have similar topics (e.g., the cluster about Charles Darwin personal life with his autobiography and letters). If you are familiar with Darwin's bibliography, the results should not surprise you too much, which indicates the method gives good results. Otherwise, next time you read one of the author's book, you will know which other books to read next in order to learn more about the topics it addressed.</p>

# %%
# Import libraries
from scipy.cluster import hierarchy

# Compute the clusters from the similarity matrix,
# using the Ward variance minimization algorithm
Z = hierarchy.linkage(sim_df, 'ward')

# Display this result as a horizontal dendrogram
a = hierarchy.dendrogram(Z,  leaf_font_size=8, labels=sim_df.index,  orientation="left")
